# %% [markdown]
# # Campervans in Switzerland

# %% [markdown]
# ## Libraries and settings

# %%
# Load Python libraries
import os
import pandas
import matplotlib.pyplot

# Ignore warnings
import warnings
warnings.filterwarnings("ignore")

# Show current working directory
print(os.getcwd())
